# %%
import pandas as pd
df = pd.read_csv('sales.csv')
df
# Out:
#         Order_ID Order_Date     Customer_Name           City          State  \
# 0              1   08-23-23      Bianca Brown        Jackson    Mississippi
# 1              2   12-20-24     Jared Edwards   Grand Rapids       Michigan
# 2              3   01-29-24      Susan Valdez    Minneapolis      Minnesota
# 3              4   11-29-24     Tina Williams    Tallahassee        Florida
# 4              5   09-21-23  Catherine Gordon      Baltimore       Maryland
# ...          ...        ...               ...            ...            ...
# 199995    199996   08-15-23   William Jackson         Boston  Massachusetts
# 199996    199997   10-17-23    Sharon Ferrell       Bismarck   North Dakota
# 199997    199998   12-03-23      Katie Rivera       Santa Fe     New Mexico
# 199998    199999   12-08-23     Lisa Sullivan  New York City       New York
# 199999    200000   12-13-24   Jessica Mueller        Augusta          Maine
#
# ...

# %%
df.head(5)
# Out:
#    Order_ID Order_Date     Customer_Name          City        State  Region  \
# 0         1   08-23-23      Bianca Brown       Jackson  Mississippi   South
# 1         2   12-20-24     Jared Edwards  Grand Rapids     Michigan  Centre
# 2         3   01-29-24      Susan Valdez   Minneapolis    Minnesota  Centre
# 3         4   11-29-24     Tina Williams   Tallahassee      Florida   South
# 4         5   09-21-23  Catherine Gordon     Baltimore     Maryland    East
#
#          Country            Category       Sub_Category      Product_Name  \
# 0  United States         Accessories  Small Electronics        Phone Case
# 1  United States         Accessories  Small Electronics    Charging Cable
# 2  United States  Clothing & Apparel         Sportswear  Nike Air Force 1
# 3  United States  Clothing & Apparel         Sportswear  Adidas Tracksuit
# 4  United States         Accessories               Bags          Backpack
#
#    Quantity   Unit_Price    Revenue    Profit
# ...

# %%
df.tail(5)
# Out:
#         Order_ID Order_Date    Customer_Name           City          State  \
# 199995    199996   08-15-23  William Jackson         Boston  Massachusetts
# 199996    199997   10-17-23   Sharon Ferrell       Bismarck   North Dakota
# 199997    199998   12-03-23     Katie Rivera       Santa Fe     New Mexico
# 199998    199999   12-08-23    Lisa Sullivan  New York City       New York
# 199999    200000   12-13-24  Jessica Mueller        Augusta          Maine
#
#         Region        Country            Category          Sub_Category  \
# 199995    East  United States    Home & Furniture               Storage
# 199996  Centre  United States         Accessories     Small Electronics
# 199997    West  United States         Accessories  Wearable Accessories
# 199998    East  United States  Clothing & Apparel          Women's Wear
# 199999    East  United States  Clothing & Apparel            Men's Wear
#
#           Product_Name  Quantity   Unit_Price    Revenue    Profit
# ...

# %%
df.describe()
# Out:
#             Order_ID       Quantity    Unit_Price        Revenue   \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean   100000.500000       1.854000     382.855615     712.038725
# std     57735.171256       1.100536     276.870235     742.471556
# min         1.000000       1.000000      17.030000      17.030000
# 25%     50000.750000       1.000000     162.760000     229.187500
# 50%    100000.500000       1.000000     303.545000     464.880000
# 75%    150000.250000       2.000000     562.252500     881.302500
# max    200000.000000      11.000000    1432.000000    9014.250000
#
#              Profit
# count  200000.000000
# mean      157.743041
# std       155.689581
# min         3.920000
# 25%        59.210000
# 50%       109.530000
# 75%       199.402500
# max      2763.720000

# %%
df.dtypes
# Out:
# Order_ID           int64
# Order_Date        object
# Customer_Name     object
# City              object
# State             object
# Region            object
# Country           object
# Category          object
# Sub_Category      object
# Product_Name      object
# Quantity           int64
#  Unit_Price      float64
#  Revenue         float64
#  Profit          float64
# dtype: object

# %%
# Handling missing values
df.isnull().any()
# Out:
# Order_ID         False
# Order_Date       False
# Customer_Name    False
# City             False
# State            False
# Region           False
# Country          False
# Category         False
# Sub_Category     False
# Product_Name     False
# Quantity         False
#  Unit_Price      False
#  Revenue         False
#  Profit          False
# dtype: bool

# %%
df = df.rename(columns={'Date':'Sales Date'})
df.head(3)
# Out:
#    Order_ID Order_Date  Customer_Name          City        State  Region  \
# 0         1   08-23-23   Bianca Brown       Jackson  Mississippi   South
# 1         2   12-20-24  Jared Edwards  Grand Rapids     Michigan  Centre
# 2         3   01-29-24   Susan Valdez   Minneapolis    Minnesota  Centre
#
#          Country            Category       Sub_Category      Product_Name  \
# 0  United States         Accessories  Small Electronics        Phone Case
# 1  United States         Accessories  Small Electronics    Charging Cable
# 2  United States  Clothing & Apparel         Sportswear  Nike Air Force 1
#
#    Quantity   Unit_Price    Revenue    Profit
# 0         3        201.01     603.03    221.49
# 1         4         74.30     297.20     97.09
# 2         1         68.19      68.19     25.47

# %%
df['Value_new']= df['Quantity'].fillna(df['Quantity']).astype(int)
df.head()
# Out:
#    Order_ID Order_Date     Customer_Name          City        State  Region  \
# 0         1   08-23-23      Bianca Brown       Jackson  Mississippi   South
# 1         2   12-20-24     Jared Edwards  Grand Rapids     Michigan  Centre
# 2         3   01-29-24      Susan Valdez   Minneapolis    Minnesota  Centre
# 3         4   11-29-24     Tina Williams   Tallahassee      Florida   South
# 4         5   09-21-23  Catherine Gordon     Baltimore     Maryland    East
#
#          Country            Category       Sub_Category      Product_Name  \
# 0  United States         Accessories  Small Electronics        Phone Case
# 1  United States         Accessories  Small Electronics    Charging Cable
# 2  United States  Clothing & Apparel         Sportswear  Nike Air Force 1
# 3  United States  Clothing & Apparel         Sportswear  Adidas Tracksuit
# 4  United States         Accessories               Bags          Backpack
#
#    Quantity   Unit_Price    Revenue    Profit   Value_new
# ...

# %%
# Data Aggregating and Grouping
df.head()
# Out:
#    Order_ID Order_Date     Customer_Name          City        State  Region  \
# 0         1   08-23-23      Bianca Brown       Jackson  Mississippi   South
# 1         2   12-20-24     Jared Edwards  Grand Rapids     Michigan  Centre
# 2         3   01-29-24      Susan Valdez   Minneapolis    Minnesota  Centre
# 3         4   11-29-24     Tina Williams   Tallahassee      Florida   South
# 4         5   09-21-23  Catherine Gordon     Baltimore     Maryland    East
#
#          Country            Category       Sub_Category      Product_Name  \
# 0  United States         Accessories  Small Electronics        Phone Case
# 1  United States         Accessories  Small Electronics    Charging Cable
# 2  United States  Clothing & Apparel         Sportswear  Nike Air Force 1
# 3  United States  Clothing & Apparel         Sportswear  Adidas Tracksuit
# 4  United States         Accessories               Bags          Backpack
#
#    Quantity   Unit_Price    Revenue    Profit   Value_new
# ...
