# %%
my_set={1,2,3,4,5}
print(my_set)
print(type(my_set))
# Out:
# {1, 2, 3, 4, 5}
# <class 'set'>

# %%
myset = set([1,2,2,1,1,55,55,43,2,3,4,5])
print(myset)
myset.remove(2)
print(myset)
print(444 in myset)
# Out:
# {1, 2, 3, 4, 5, 43, 55}
# {1, 3, 4, 5, 43, 55}
# False
