# %%
import array
arr=array.array('i',[1,2,3,4,5])
print(arr)
# Out:
# array('i', [1, 2, 3, 4, 5])

# %%
import math
print(math.sqrt(100))
# Out:
# 10.0

# %%
import random
print(random.randint(1,10))
print(random.choice(['apple','banana','red','yellow']))
# Out:
# 8
# yellow

# %%
import os
print(os.getcwd)
# Out:
# <built-in function getcwd>

# %%
from datetime import datetime,timedelta

now = datetime.now()
print(now)
yester = now - timedelta(days=12)
print(yester)
# Out:
# 2026-04-28 23:35:33.846302
# 2026-04-16 23:35:33.846302
