# %%
def addition(a,b):
    print(a+b)

# %%
addition(5,5)
# Out:
# 10

# %%
add = lambda a,b:a+b
type(add)
print(add(5,10))
# Out:
# 15

# %%
def even(num):
    if num%2==0:
        return True
    else:
        return False
even(45)
# Out:
# False

# %%
evcen=lambda num:num%2==0
evcen(34)
# Out:
# True

# %%
numbers = [1,2,3,4,5,6]
def sqr(number):
    return number**2
sqr(11)
# Out:
# 121

# %%
list(map(lambda x:x**2,numbers))
# Out:
# [1, 4, 9, 16, 25, 36]
